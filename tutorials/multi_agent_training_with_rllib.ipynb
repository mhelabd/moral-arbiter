# %% [markdown]
# Copyright (c) 2021, salesforce.com, inc.
# All rights reserved.
# SPDX-License-Identifier: BSD-3-Clause
# For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause

# %% [markdown]
# ### Colab
#
# Try this notebook on [Colab](http://colab.research.google.com/github/salesforce/ai-economist/blob/master/tutorials/multi_agent_training_with_rllib.ipynb).

# %% [markdown]
# ### Prerequisites
# It is helpful to be familiar with **Foundation**, a multi-agent economic simulator built for the AI Economist ([paper here](https://arxiv.org/abs/2004.13332)). If you haven't worked with Foundation before, we highly recommend taking a look at our other tutorials:
#
# - [Foundation: the Basics](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb)
# - [Extending Foundation](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_advanced.ipynb)
# - [Optimal Taxation Theory and Simulation](https://github.com/salesforce/ai-economist/blob/master/tutorials/optimal_taxation_theory_and_simulation.ipynb)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Welcome! This tutorial is the first of a series on doing distributed multi-agent reinforcement learning (MARL). Here, we specifically demonstrate how to integrate our multi-agent economic simulation, [Foundation](https://github.com/salesforce/ai-economist/tree/master/ai_economist/foundation), with [RLlib](https://github.com/ray-project/ray/tree/master/rllib), an open-source library for reinforcement learning. We chose to use RLlib, as it provides an easy-to-use and flexible library for MARL. A detailed documentation on RLlib is available [here](https://docs.ray.io/en/master/rllib.html).
#
# We put together these tutorial notebook with the following key goals in mind:
# - Provide an exposition to MARL. While there are many libraries and references out there for single-agent RL training, MARL training is not discussed as much, and there aren't many multi-agent rl libraries.
# - Provide reference starting code to perform MARL training so the AI Economist community can focus more on building meaningful extensions to Foundation and better-performant algorithms.
#
# We will cover the following concepts in this tutorial:
# 1. Adding an *environment wrapper* to make the economic simulation compatible with RLlib.
# 2. Creating a *trainer* object that holds the (multi-agent) policies for environment interaction.
# 3. Training all the agents in the economic simulation.
# 4. Generate a rollout using the trainer object and visualize it.

# %% [markdown]
# ### Dependencies:
# You can install the ai-economist package using
# - the pip package manager OR
# - by cloning the ai-economist package and installing the requirements (we shall use this when running on Colab):

# %% [markdown]
# Install OpenAI Gym to help define the environment's observation and action spaces for use with RLlib.

# %% [markdown]
# Install the `RLlib` reinforcement learning library:
# - First, install TensorFlow
# - Then, install ray[rllib]
#
# Note: RLlib natively supports TensorFlow (including TensorFlow Eager) as well as PyTorch, but most of its internals are framework agnostic. Here's a relevant [blogpost](https://medium.com/distributed-computing-with-ray/lessons-from-implementing-12-deep-rl-algorithms-in-tf-and-pytorch-1b412009297d) that compares running RLlib algorithms with TF and PyTorch. Overall, TF seems to run a bit faster than PyTorch, in our experience, and we will use that in this notebook.

# %%
# Change directory to the tutorials folder
import os, sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    os.chdir("/content/ai-economist/tutorials")
else:
    os.chdir(os.path.dirname(os.path.abspath("__file__"))
)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /home/mhelabd/anaconda3/envs/ai-ethicist/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ## 1. Adding an Environment Wrapper

# %% [markdown]
# We first define a configuration (introduced in [the basics tutorial](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basics.ipynb)) for the "gather-trade-build" environment with multiple mobile agents (that move, gather resources, build or trade) and a social planner that sets taxes according to (a scaled variant of) the 2018 US tax schedule.

# %%
lambd = 1
ethics = 'amoral'

# %%
# Define a configuration (dictionary) for the "gather-trade-build" environment.

env_config_dict = {
    # ===== SCENARIO CLASS =====
    # Which Scenario class to use: the class's name in the Scenario Registry (foundation.scenarios).
    # The environment object will be an instance of the Scenario class.
    'scenario_name': 'moral_uniform/simple_wood_and_stone',
#         ===== MORALITY =====
    'moral_theory': ethics, 
#     'agent_morality': lambd, 
#     'scenario_name': 'uniform/simple_wood_and_stone',
    
    
    
    # ===== COMPONENTS =====
    # Which components to use (specified as list of ("component_name", {component_kwargs}) tuples).
    #   "component_name" refers to the Component class's name in the Component Registry (foundation.components)
    #   {component_kwargs} is a dictionary of kwargs passed to the Component class
    # The order in which components reset, step, and generate obs follows their listed order below.
    'components': [
        # (1) Building houses
        ('Build', {
            'skill_dist':                   'pareto', 
            'payment_max_skill_multiplier': 3,
            'build_labor':                  10,
            'payment':                      10
        }),
        # (2) Trading collectible resources
        ('ContinuousDoubleAuction', {
            'max_bid_ask':    10,
            'order_labor':    0.25,
            'max_num_orders': 5,
            'order_duration': 50
        }),
        # (3) Movement and resource collection
        ('Gather', {
            'move_labor':    1,
            'collect_labor': 1,
            'skill_dist':    'pareto'
        }),
#         (4) Stealing,
        ('Steal', {
            'steal_labor':    1,
            'skill_dist':    'pareto'  
        }),
    ],
    
    
    # ===== SCENARIO CLASS ARGUMENTS =====
    # (optional) kwargs that are added by the Scenario class (i.e. not defined in BaseEnvironment)
    'starting_agent_coin': 10,
    
    # ===== STANDARD ARGUMENTS ======
    # kwargs that are used by every Scenario class (i.e. defined in BaseEnvironment)
    'n_agents': 4,          # Number of non-planner agents (must be > 1)
    'world_size': [25, 25], # [Height, Width] of the env world
    'episode_length': 1000, # Number of timesteps per episode
    
    # In multi-action-mode, the policy selects an action for each action subspace (defined in component code).
    # Otherwise, the policy selects only 1 action.
    'multi_action_mode_agents': False,
    'multi_action_mode_planner': True,
    
    # When flattening observations, concatenate scalar & vector observations before output.
    # Otherwise, return observations with minimal processing.
    'flatten_observations': True,
    # When Flattening masks, concatenate each action subspace mask into a single array.
    # Note: flatten_masks = True is required for masking action logits in the code below.
    'flatten_masks': True,
    
    # How often to save the dense logs
    'dense_log_frequency': 1
}

# %% [markdown]
# Like we have seen in earlier [tutorials](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb), using `env = foundation.make_env_instance(**env_config)` creates an environment instance `env` with the specified configuration.
#
# In order to use this environment with RLlib, we will also need to add the environment's `observation_space` and `action_space` attributes. Additionally, the environment itself must subclass the [`MultiAgentEnv`](https://github.com/ray-project/ray/blob/master/rllib/env/multi_agent_env.py) interface, which can return observations and rewards from multiple ready agents per step. To this end, we use an environment [wrapper](https://github.com/salesforce/ai-economist/blob/master/tutorials/rllib/env_wrapper.py).

# %%
from rllib.env_wrapper import RLlibEnvWrapper
env_obj = RLlibEnvWrapper({"env_config_dict": env_config_dict}, verbose=True)
# Out:
# Inside covid19_components.py: 1 GPUs are available.
# Inside covid19_env.py: 1 GPUs are available.
# /home/mhelabd/anaconda3/envs/ai-ethicist/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# [EnvWrapper] Spaces
# [EnvWrapper] Obs (a)
# action_mask    : (51,)
# flat           : (122,)
# time           : (1,)
# world-idx_map  : (2, 11, 11)
# world-map      : (6, 11, 11)
#
#
# [EnvWrapper] Obs (p)
# action_mask    : (1,)
# flat           : (72,)
# p0             : (5,)
# p1             : (5,)
# p2             : (5,)
# p3             : (5,)
# time           : (1,)
# world-idx_map  : (2, 25, 25)
# world-map      : (5, 25, 25)
#
#
# [EnvWrapper] Action (a) Discrete(51)
# [EnvWrapper] Action (p) MultiDiscrete([1])

# %% [markdown]
# Upon applying the wrapper to our environment, we have now defined observation and action spaces for the agents and the planner, indicated with `(a)` and `(p)` respectively. Also, (a useful tip) you can still access the environment instance and its attributes simply by using `env_obj.env`
#
# In summary, the observation spaces are represented as `Box` objects and the action spaces as `Discrete` objects (for more details on these types, see the OpenAI documentation [page](https://gym.openai.com/docs/#spaces)).
#
# Briefly looking at the shapes of the observation features (the numbers in parentheses), you will see that we have some one-dimensional features (e.g. `action-mask`, `flat`, `time`) as well as spatial features (e.g., `world-idx-map`, `world-map`)
#
# A couple of quick notes:
# - An `action_mask` is used to mask out the actions that are not allowed by the environment. For instance, a mobile agent cannot move beyond the boundary of the world. Hence, in position (0, 0), a mobile cannot move "Left" or "Down", and the corresponding actions in the mask would be nulled out. Now, the RL agent can still recommend to move "Left" or "Down", but the action isn't really taken.
# - The key `flat` arises since we set `flatten_observations': True`. Accordingly, the scalar and vector raw observations are all concatenated into this single key. If you're curious to see the entire set of raw observations, do set `flatten_observations': False` in the env_config, and re-run the above cell.
#
# Looking at the action spaces, the mobile agents can take 50 possible actions (including 1 NO-OP action or do nothing (always indexed 0), 44 trading-related actions, 4 move actions along the four directions and 1 build action)
#
# The planner sets the tax rates for 7 brackets, each from 0-100% in steps of 5%, so that's 21 values. Adding the NO-OP action brings the planner action space to `MultiDiscrete([22 22 22 22 22 22 22])`.

# %% [markdown]
# ## 2. Creating a *Trainer* Object

# %% [markdown]
# In order to train our economic simulation environment with RLlib, you will need familiarity with one of the key classes: the [`Trainer`](https://docs.ray.io/en/master/rllib-training.html). The trainer object maintains the relationships that connect each agent in the environment to its corresponding trainable policy, and essentially helps in training, checkpointing policies and inferring actions. It helps to co-ordinate the workflow of collecting rollouts and optimizing the various policies via a reinforcement learning algorithm. Inherently, RLlib maintains a wide suite of [algorithms](https://docs.ray.io/en/master/rllib-algorithms.html) for multi-agent learning (which was another strong reason for us to consider using RLlib) - available options include SAC, PPO, PG, A2C, A3C, IMPALA, ES, DDPG, DQN, MARWIL, APEX, and APEX_DDPG. For the remainder of this tutorial, we will stick to using [Proximal Policy Optimization](https://openai.com/blog/openai-baselines-ppo/) (PPO), an algorithm known to perform well generally.
#
# Every algorithm has a corresponding trainer object; in the context of PPO, we invoke the `PPOTrainer` object.

# %%
import ray
from ray.rllib.agents.dqn import DQNTrainer
from ray.rllib.agents.ppo import PPOTrainer

# %% [markdown]
# PPOTrainer can be instantiated with
# - `env`: an environment creator (i.e, RLlibEnvWrapper() in our case)
# - `config`: algorithm-specific configuration data for setting the various components of the RL training loop including the environment, rollout worker processes, training resources, degree of parallelism, framework used, and the policy exploration strategies.
#
# Note: There are several configuration settings related to policy architectures, rollout collection, minibatching, and other important hyperparameters, that need to be set carefully in order to train effectively. For the sake of the high-level exposition, we allow RLlib to use most of the the default settings. Check out the list of default [common configuration parameters](https://docs.ray.io/en/releases-0.8.4/rllib-training.html#common-parameters) and default [PPO-specific configuration parameters](https://docs.ray.io/en/releases-0.8.4/rllib-algorithms.html?highlight=PPO#proximal-policy-optimization-ppo). Custom environment configurations may be passed to environment creator via `config["env_config"]`.
#
# RLlib also chooses default built-in [models](https://docs.ray.io/en/releases-0.8.4/rllib-models.html#built-in-models-and-preprocessors) for processing the observations. The models are picked based on a simple heuristic: a [vision](https://github.com/ray-project/ray/blob/master/rllib/models/tf/visionnet.py) network for observations that have shape of length larger than 2 (for example, (84 x 84 x 3)), and a [fully connected](https://github.com/ray-project/ray/blob/master/rllib/models/tf/fcnet.py) network for everything else. Custom models can be configured via the `config["policy"]["model"]` key.
#
# In the context of multi-agent training, we will also need to set the multi-agent configuration:
# ```python
# "multiagent": {
#         # Map of type MultiAgentPolicyConfigDict from policy ids to tuples
#         # of (policy_cls, obs_space, act_space, config). This defines the
#         # observation and action spaces of the policies and any extra config.
#         "policies": {},
#         # Function mapping agent ids to policy ids.
#         "policy_mapping_fn": None,
#         # Optional list of policies to train, or None for all policies.
#         "policies_to_train": None,
#     },
# ```
#
# To this end, let's notate the agent policy id by `"a"` and the planner policy id by `"p"`. We can set `policies`, `policy_mapping_fun` and `policies_to_train` as follows.

# %%
policies = {
    "a": (
        None,  # uses default policy
        env_obj.observation_space,
        env_obj.action_space,
        {}  # define a custom agent policy configuration.
    ),
    "p": (
        None,  # uses default policy
        env_obj.observation_space_pl,
        env_obj.action_space_pl,
        {}  # define a custom planner policy configuration.
    )
}

# In foundation, all the agents have integer ids and the social planner has an id of "p"
policy_mapping_fun = lambda i: "a" if str(i).isdigit() else "p"

policies_to_train = ["a", "p"]

# %% [markdown]
# Create a multiagent trainer config holding the trainable policies and their mappings.

# %%
trainer_config = {
    "multiagent": {
        "policies": policies,
        "policies_to_train": policies_to_train,
        "policy_mapping_fn": policy_mapping_fun,
    }
}

# %% [markdown]
# With distributed RL, architectures typically comprise several **roll-out** and **trainer** workers operating in tandem
# ![](assets/distributed_rl_architecture.png)
#
# The roll-out workers repeatedly step through the environment to generate and collect roll-outs in parallel, using the actions sampled from the policy models on the roll-out workers or provided by the trainer worker.
# Roll-out workers typically use CPU machines, and sometimes, GPU machines for richer environments.
# Trainer workers gather the roll-out data (asynchronously) from the roll-out workers and optimize policies on CPU or GPU machines.
#
# In this context, we can also add a `num_workers` configuration parameter to specify the number of rollout workers, i.e, those responsible for gathering rollouts. Note: setting `num_workers=0` will mean the rollouts will be collected by the trainer worker itself. Also, each worker can collect rollouts from multiple environments in parallel, which is specified in `num_envs_per_worker`; there will be a total of `num_workers` $\times$ `num_envs_per_worker` environment replicas used to gather rollouts.
# Note: below, we also update some of the default trainer settings to keep the iteration time small.

# %%
trainer_config.update(
    {
        "num_workers": 2,
        "num_envs_per_worker": 2,
        # Other training parameters
        "train_batch_size":  4000,
        "sgd_minibatch_size": 4000,
        "num_sgd_iter": 1
    }
)

# %% [markdown]
# Finally, we need to add the environment configuration to the trainer configuration.

# %%
# We also add the "num_envs_per_worker" parameter for the env. wrapper to index the environments.
env_config = {
    "env_config_dict": env_config_dict,
    "num_envs_per_worker": trainer_config.get('num_envs_per_worker'),   
}

trainer_config.update(
    {
        "env_config": env_config, 
    }
)

# %% [markdown]
# One the training configuration is set, we will need to initialize ray and create the PPOTrainer object.

# %%
# Initialize Ray
ray.init()
# Out:
# 2022-02-05 18:37:30,659	INFO resource_spec.py:212 -- Starting Ray with 75.54 GiB memory available for workers and up to 36.37 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2022-02-05 18:37:31,145	INFO services.py:1148 -- View the Ray dashboard at localhost:8265
# {'node_ip_address': '171.67.84.226',
#  'redis_address': '171.67.84.226:37959',
#  'object_store_address': '/tmp/ray/session_2022-02-05_18-37-30_657435_13758/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2022-02-05_18-37-30_657435_13758/sockets/raylet',
#  'webui_url': 'localhost:8265',
#  'session_dir': '/tmp/ray/session_2022-02-05_18-37-30_657435_13758'}

# %%
# Create the PPO trainer.
# TODO: MAKE Q-LEARNING 
trainer = PPOTrainer(
    env=RLlibEnvWrapper,
    config=trainer_config,
    )
# Out:
# (pid=13874) /home/mhelabd/anaconda3/envs/ai-ethicist/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
# (pid=13874)   for external in metadata.entry_points().get(self.group, []):
# (pid=13884) /home/mhelabd/anaconda3/envs/ai-ethicist/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
# (pid=13884)   for external in metadata.entry_points().get(self.group, []):
# (pid=13874) Inside covid19_components.py: 1 GPUs are available.
# (pid=13884) Inside covid19_components.py: 1 GPUs are available.
# (pid=13874) Inside covid19_env.py: 1 GPUs are available.
# (pid=13884) Inside covid19_env.py: 1 GPUs are available.
# 2022-02-05 18:37:40,081	INFO trainable.py:217 -- Getting current IP.

# %% [markdown]
# ## 3. Perform Training

# %% [markdown]
# And that's it! We are now ready to perform training by invoking `trainer.train()`; we call it for just a few number of iterations.

# %%
NUM_ITERS = 2000
for iteration in range(NUM_ITERS):
    print(f'********** Iter : {iteration} **********')
    result = trainer.train()
    print(f'''episode_reward_mean: {result.get('episode_reward_mean')}''')
# Out:
# ********** Iter : 0 **********
# episode_reward_mean: -6676.313833429832
# ********** Iter : 1 **********
# episode_reward_mean: -6196.387067780707
# ********** Iter : 2 **********
# episode_reward_mean: -6187.930477719945
# ********** Iter : 3 **********
# episode_reward_mean: -6255.048579883284
# ********** Iter : 4 **********
# episode_reward_mean: -6145.337092882949
# ********** Iter : 5 **********
# episode_reward_mean: -6008.784105530749
# ********** Iter : 6 **********
# episode_reward_mean: -6040.061484533622
# ********** Iter : 7 **********
# episode_reward_mean: -5906.802783996926
# ********** Iter : 8 **********
# episode_reward_mean: -5927.562154707591
# ********** Iter : 9 **********
# episode_reward_mean: -5785.9580168152925
# ********** Iter : 10 **********
# episode_reward_mean: -5705.4805933177695
# ********** Iter : 11 **********
# episode_reward_mean: -5619.524293584611
# ********** Iter : 12 **********
# episode_reward_mean: -5519.459826790082
# ********** Iter : 13 **********
# episode_reward_mean: -5518.283921259589
# ********** Iter : 14 **********
# episode_reward_mean: -5423.069295303623
# ********** Iter : 15 **********
# episode_reward_mean: -5374.593071253695
# ********** Iter : 16 **********
# episode_reward_mean: -5253.867229784201
# ********** Iter : 17 **********
# episode_reward_mean: -5151.632887818926
# ********** Iter : 18 **********
# episode_reward_mean: -5086.477102012582
# ********** Iter : 19 **********
# episode_reward_mean: -4975.729659371514
# ********** Iter : 20 **********
# episode_reward_mean: -4857.1926587828975
# ********** Iter : 21 **********
# episode_reward_mean: -4808.503850506094
# ********** Iter : 22 **********
# episode_reward_mean: -4700.847404819183
# ********** Iter : 23 **********
# episode_reward_mean: -4511.276679635219
# ********** Iter : 24 **********
# episode_reward_mean: -4332.713827871261
# ********** Iter : 25 **********
# episode_reward_mean: -4124.687456485026
# ********** Iter : 26 **********
# episode_reward_mean: -3996.764244701302
# ********** Iter : 27 **********
# episode_reward_mean: -3803.1276633355596
# ********** Iter : 28 **********
# episode_reward_mean: -3588.7961205408938
# ********** Iter : 29 **********
# episode_reward_mean: -3417.769281376149
# ********** Iter : 30 **********
# episode_reward_mean: -3276.4487941030584
# ********** Iter : 31 **********
# episode_reward_mean: -3075.053260940794
# ********** Iter : 32 **********
# episode_reward_mean: -2969.8620863320084
# ********** Iter : 33 **********
# episode_reward_mean: -2779.9251019465114
# ********** Iter : 34 **********
# episode_reward_mean: -2648.6726019465113
# ********** Iter : 35 **********
# episode_reward_mean: -2525.8369931489947
# ********** Iter : 36 **********
# episode_reward_mean: -2394.2594431001858
# ********** Iter : 37 **********
# episode_reward_mean: -2264.205359766852
# ********** Iter : 38 **********
# episode_reward_mean: -2081.546546234764
# ********** Iter : 39 **********
# episode_reward_mean: -1954.0745933677704
# ********** Iter : 40 **********
# episode_reward_mean: -1799.7690987049077
# ********** Iter : 41 **********
# episode_reward_mean: -1704.3023487049074
# ********** Iter : 42 **********
# episode_reward_mean: -1618.1429298949247
# ********** Iter : 43 **********
# episode_reward_mean: -1495.0058077928313
# ********** Iter : 44 **********
# episode_reward_mean: -1420.45999419906
# ********** Iter : 45 **********
# episode_reward_mean: -1359.063864952414
# ********** Iter : 46 **********
# episode_reward_mean: -1240.3515464703462
# ********** Iter : 47 **********
# episode_reward_mean: -1175.133983970346
# ********** Iter : 48 **********
# episode_reward_mean: -1127.60131730368
# ********** Iter : 49 **********
# episode_reward_mean: -1081.360282505304
# ********** Iter : 50 **********
# episode_reward_mean: -1015.6703764595914
# ********** Iter : 51 **********
# episode_reward_mean: -971.6692965766474
# ********** Iter : 52 **********
# episode_reward_mean: -946.144963243314
# ********** Iter : 53 **********
# episode_reward_mean: -912.3593174099806
# ********** Iter : 54 **********
# episode_reward_mean: -894.7598583551178
# ********** Iter : 55 **********
# episode_reward_mean: -860.831276198928
# ********** Iter : 56 **********
# episode_reward_mean: -831.6161303655946
# ********** Iter : 57 **********
# episode_reward_mean: -772.1910133077131
# ********** Iter : 58 **********
# episode_reward_mean: -736.7477632206408
# ********** Iter : 59 **********
# episode_reward_mean: -715.3264715539739
# ********** Iter : 60 **********
# episode_reward_mean: -661.9991240642578
# ********** Iter : 61 **********
# episode_reward_mean: -629.3364365642578
# ********** Iter : 62 **********
# episode_reward_mean: -608.8983740642578
# ********** Iter : 63 **********
# episode_reward_mean: -591.2541448975911
# ********** Iter : 64 **********
# episode_reward_mean: -578.716894897591
# ********** Iter : 65 **********
# episode_reward_mean: -571.0178740642577
# ********** Iter : 66 **********
# episode_reward_mean: -572.6162040661377
# ********** Iter : 67 **********
# episode_reward_mean: -559.6044280903058
# ********** Iter : 68 **********
# episode_reward_mean: -544.7700322569724
# ********** Iter : 69 **********
# episode_reward_mean: -528.4658654610463
# ********** Iter : 70 **********
# episode_reward_mean: -512.8456197076925
# ********** Iter : 71 **********
# episode_reward_mean: -497.14942528417544
# ********** Iter : 72 **********
# episode_reward_mean: -503.51566108005346
# ********** Iter : 73 **********
# episode_reward_mean: -487.29045274671995
# ********** Iter : 74 **********
# episode_reward_mean: -476.6049110800534
# ********** Iter : 75 **********
# episode_reward_mean: -462.6753902467201
# ********** Iter : 76 **********
# episode_reward_mean: -462.1479944133867
# ********** Iter : 77 **********
# episode_reward_mean: -449.16728608005343
# ********** Iter : 78 **********
# episode_reward_mean: -460.3753052222078
# ********** Iter : 79 **********
# episode_reward_mean: -444.5149391065783
# ********** Iter : 80 **********
# episode_reward_mean: -428.5602516065784
# ********** Iter : 81 **********
# episode_reward_mean: -413.5242724399117
# ********** Iter : 82 **********
# episode_reward_mean: -407.2696266065783
# ********** Iter : 83 **********
# episode_reward_mean: -406.78114743991165
# ********** Iter : 84 **********
# episode_reward_mean: -397.50779327324506
# ********** Iter : 85 **********
# episode_reward_mean: -397.79256410657837
# ********** Iter : 86 **********
# episode_reward_mean: -390.0118349399118
# ********** Iter : 87 **********
# episode_reward_mean: -385.37418910657834
# ********** Iter : 88 **********
# episode_reward_mean: -370.9483557732451
# ********** Iter : 89 **********
# episode_reward_mean: -367.0735641065785
# ********** Iter : 90 **********
# episode_reward_mean: -359.37598077324515
# ********** Iter : 91 **********
# episode_reward_mean: -342.9970466046984
# ********** Iter : 92 **********
# episode_reward_mean: -334.07975667892157
# ********** Iter : 93 **********
# episode_reward_mean: -331.8622983455882
# ********** Iter : 94 **********
# episode_reward_mean: -328.3339650122549
# ********** Iter : 95 **********
# episode_reward_mean: -346.8306862226182
# ********** Iter : 96 **********
# episode_reward_mean: -347.8275195559516
# ********** Iter : 97 **********
# episode_reward_mean: -331.1491170934071
# ********** Iter : 98 **********
# episode_reward_mean: -327.7013879267404
# ********** Iter : 99 **********
# episode_reward_mean: -326.4546379267405
# ********** Iter : 100 **********
# episode_reward_mean: -335.3308462600737
# ********** Iter : 101 **********
# episode_reward_mean: -338.4763462600737
# ********** Iter : 102 **********
# episode_reward_mean: -330.9092212600737
# ********** Iter : 103 **********
# episode_reward_mean: -313.1364937845859
# ********** Iter : 104 **********
# episode_reward_mean: -318.63668128458596
# ********** Iter : 105 **********
# episode_reward_mean: -315.9573062845859
# ********** Iter : 106 **********
# episode_reward_mean: -318.6109104512526
# ********** Iter : 107 **********
# episode_reward_mean: -307.0170771179193
# ********** Iter : 108 **********
# episode_reward_mean: -299.3634521179193
# ********** Iter : 109 **********
# episode_reward_mean: -296.10209795125263
# ********** Iter : 110 **********
# episode_reward_mean: -295.0119729512527
# ********** Iter : 111 **********
# episode_reward_mean: -291.2674729512526
# ********** Iter : 112 **********
# episode_reward_mean: -286.25128545125267
# ********** Iter : 113 **********
# episode_reward_mean: -284.53128545125264
# ********** Iter : 114 **********
# episode_reward_mean: -290.4045771179194
# ********** Iter : 115 **********
# episode_reward_mean: -284.2191396179194
# ********** Iter : 116 **********
# episode_reward_mean: -282.5378062845861
# ********** Iter : 117 **********
# episode_reward_mean: -266.02688787702965
# ********** Iter : 118 **********
# episode_reward_mean: -293.6424716886848
# ********** Iter : 119 **********
# episode_reward_mean: -289.6582425220182
# ********** Iter : 120 **********
# episode_reward_mean: -262.19806297832156
# ********** Iter : 121 **********
# episode_reward_mean: -259.7810004783215
# ********** Iter : 122 **********
# episode_reward_mean: -255.84002131165485
# ********** Iter : 123 **********
# episode_reward_mean: -258.31312547832147
# ********** Iter : 124 **********
# episode_reward_mean: -261.23735464498816
# ********** Iter : 125 **********
# episode_reward_mean: -246.45416714498822
# ********** Iter : 126 **********
# episode_reward_mean: -234.17270881165484
# ********** Iter : 127 **********
# episode_reward_mean: -238.77089631165484
# ********** Iter : 128 **********
# episode_reward_mean: -234.7917713116548
# ********** Iter : 129 **********
# episode_reward_mean: -224.8946671449882
# ********** Iter : 130 **********
# episode_reward_mean: -219.47077131165486
# ********** Iter : 131 **********
# episode_reward_mean: -218.55658381165486
# ********** Iter : 132 **********
# episode_reward_mean: -220.26204214498821
# ********** Iter : 133 **********
# episode_reward_mean: -217.6164796449882
# ********** Iter : 134 **********
# episode_reward_mean: -217.56750047832148
# ********** Iter : 135 **********
# episode_reward_mean: -217.09737547832148
# ********** Iter : 136 **********
# episode_reward_mean: -221.04033381165485
# ********** Iter : 137 **********
# episode_reward_mean: -220.2212088116548
# ********** Iter : 138 **********
# episode_reward_mean: -230.69752131165478
# ********** Iter : 139 **********
# episode_reward_mean: -220.35668797832147
# ********** Iter : 140 **********
# episode_reward_mean: -223.7492088116548
# ********** Iter : 141 **********
# episode_reward_mean: -224.22910464498815
# ********** Iter : 142 **********
# episode_reward_mean: -229.93050047832145
# ********** Iter : 143 **********
# episode_reward_mean: -195.39320833333292
# ********** Iter : 144 **********
# episode_reward_mean: -195.55931249999955
# ********** Iter : 145 **********
# episode_reward_mean: -208.54045833333285
# ********** Iter : 146 **********
# episode_reward_mean: -204.36610416666622
# ********** Iter : 147 **********
# episode_reward_mean: -202.6816874999995
# ********** Iter : 148 **********
# episode_reward_mean: -199.76870833333288
# ********** Iter : 149 **********
# episode_reward_mean: -200.42560416666618
# ********** Iter : 150 **********
# episode_reward_mean: -210.44222916666615
# ********** Iter : 151 **********
# episode_reward_mean: -210.83329166666618
# ********** Iter : 152 **********
# episode_reward_mean: -203.00847916666618
# ********** Iter : 153 **********
# episode_reward_mean: -202.6931041666662
# ********** Iter : 154 **********
# episode_reward_mean: -195.23083333333284
# ********** Iter : 155 **********
# episode_reward_mean: -194.84152083333288
# ********** Iter : 156 **********
# episode_reward_mean: -193.56624999999948
# ********** Iter : 157 **********
# episode_reward_mean: -191.08487499999944
# ********** Iter : 158 **********
# episode_reward_mean: -185.6537291666662
# ********** Iter : 159 **********
# episode_reward_mean: -184.18420833333286
# ********** Iter : 160 **********
# episode_reward_mean: -174.87927083333292
# ********** Iter : 161 **********
# episode_reward_mean: -173.0839374999995
# ********** Iter : 162 **********
# episode_reward_mean: -177.33552083333288
# ********** Iter : 163 **********
# episode_reward_mean: -171.86168749999956
# ********** Iter : 164 **********
# episode_reward_mean: -167.6555416666662
# ********** Iter : 165 **********
# episode_reward_mean: -194.76444272000296
# ********** Iter : 166 **********
# episode_reward_mean: -189.99781772000293
# ********** Iter : 167 **********
# episode_reward_mean: -188.38558855333628
# ********** Iter : 168 **********
# episode_reward_mean: -187.22960938666958
# ********** Iter : 169 **********
# episode_reward_mean: -193.83321355333624
# ********** Iter : 170 **********
# episode_reward_mean: -191.03246355333624
# ********** Iter : 171 **********
# episode_reward_mean: -201.63994272000284
# ********** Iter : 172 **********
# episode_reward_mean: -201.4845468866696
# ********** Iter : 173 **********
# episode_reward_mean: -207.40096355333623
# ********** Iter : 174 **********
# episode_reward_mean: -200.5145885533362
# ********** Iter : 175 **********
# episode_reward_mean: -190.99475522000293
# ********** Iter : 176 **********
# episode_reward_mean: -184.205067720003
# ********** Iter : 177 **********
# episode_reward_mean: -187.06535938666963
# ********** Iter : 178 **********
# episode_reward_mean: -195.14825522000294
# ********** Iter : 179 **********
# episode_reward_mean: -198.1541718866696
# ********** Iter : 180 **********
# episode_reward_mean: -197.8673593866696
# ********** Iter : 181 **********
# episode_reward_mean: -193.33596355333628
# ********** Iter : 182 **********
# episode_reward_mean: -190.97410938666965
# ********** Iter : 183 **********
# episode_reward_mean: -198.42413022000292
# ********** Iter : 184 **********
# episode_reward_mean: -198.0310677200029
# ********** Iter : 185 **********
# episode_reward_mean: -200.09485938666958
# ********** Iter : 186 **********
# episode_reward_mean: -209.84973438666955
# ********** Iter : 187 **********
# episode_reward_mean: -211.22467188666957
# ********** Iter : 188 **********
# episode_reward_mean: -207.21748438666955
# ********** Iter : 189 **********
# episode_reward_mean: -207.16663022000287
# ********** Iter : 190 **********
# episode_reward_mean: -174.76743749999952
# ********** Iter : 191 **********
# episode_reward_mean: -169.5337083333329
# ********** Iter : 192 **********
# episode_reward_mean: -163.8692291666662
# ********** Iter : 193 **********
# episode_reward_mean: -167.58166666666617
# ********** Iter : 194 **********
# episode_reward_mean: -162.04981249999955
# ********** Iter : 195 **********
# episode_reward_mean: -153.13479166666622
# ********** Iter : 196 **********
# episode_reward_mean: -144.9985208333329
# ********** Iter : 197 **********
# episode_reward_mean: -151.15468749999954
# ********** Iter : 198 **********
# episode_reward_mean: -141.94327083333295
# ********** Iter : 199 **********
# episode_reward_mean: -171.44191883359667
# ********** Iter : 200 **********
# episode_reward_mean: -175.10196050026335
# ********** Iter : 201 **********
# episode_reward_mean: -175.49137716693
# ********** Iter : 202 **********
# episode_reward_mean: -173.81743966692997
# ********** Iter : 203 **********
# episode_reward_mean: -174.90383550026334
# ********** Iter : 204 **********
# episode_reward_mean: -170.35248133359667
# ********** Iter : 205 **********
# episode_reward_mean: -172.62839800026333
# ********** Iter : 206 **********
# episode_reward_mean: -180.3811063335966
# ********** Iter : 207 **********
# episode_reward_mean: -207.94842258488106
# ********** Iter : 208 **********
# episode_reward_mean: -207.22315175154773
# ********** Iter : 209 **********
# episode_reward_mean: -211.48833925154773
# ********** Iter : 210 **********
# episode_reward_mean: -208.4332350848811
# ********** Iter : 211 **********
# episode_reward_mean: -198.81698508488114
# ********** Iter : 212 **********
# episode_reward_mean: -191.33946425154784
# ********** Iter : 213 **********
# episode_reward_mean: -192.63246425154776
# ********** Iter : 214 **********
# episode_reward_mean: -193.4358809182145
# ********** Iter : 215 **********
# episode_reward_mean: -200.11127675154773
# ********** Iter : 216 **********
# episode_reward_mean: -200.6827559182144
# ********** Iter : 217 **********
# episode_reward_mean: -205.62456841821444
# ********** Iter : 218 **********
# episode_reward_mean: -253.17119845373725
# ********** Iter : 219 **********
# episode_reward_mean: -250.3413234537373
# ********** Iter : 220 **********
# episode_reward_mean: -250.71569845373725
# ********** Iter : 221 **********
# episode_reward_mean: -245.07965678707063
# ********** Iter : 222 **********
# episode_reward_mean: -237.03455262040399
# ********** Iter : 223 **********
# episode_reward_mean: -237.03051095373735
# ********** Iter : 224 **********
# episode_reward_mean: -209.01509212014017
# ********** Iter : 225 **********
# episode_reward_mean: -209.35082128680685
# ********** Iter : 226 **********
# episode_reward_mean: -214.11852962014018
# ********** Iter : 227 **********
# episode_reward_mean: -225.71686295347345
# ********** Iter : 228 **********
# episode_reward_mean: -213.56327962014024
# ********** Iter : 229 **********
# episode_reward_mean: -219.41582128680685
# ********** Iter : 230 **********
# episode_reward_mean: -219.71621712014013
# ********** Iter : 231 **********
# episode_reward_mean: -221.30370476242533
# ********** Iter : 232 **********
# episode_reward_mean: -192.95528434447417
# ********** Iter : 233 **********
# episode_reward_mean: -183.9739093444742
# ********** Iter : 234 **********
# episode_reward_mean: -184.65240934447422
# ********** Iter : 235 **********
# episode_reward_mean: -187.92482601114088
# ********** Iter : 236 **********
# episode_reward_mean: -184.3794093444742
# ********** Iter : 237 **********
# episode_reward_mean: -183.96365934447422
# ********** Iter : 238 **********
# episode_reward_mean: -179.64199267780756
# ********** Iter : 239 **********
# episode_reward_mean: -181.56245101114087
# ********** Iter : 240 **********
# episode_reward_mean: -178.1712218444742
# ********** Iter : 241 **********
# episode_reward_mean: -183.28078434447423
# ********** Iter : 242 **********
# episode_reward_mean: -182.85305517780753
# ********** Iter : 243 **********
# episode_reward_mean: -129.94675847561808
# ********** Iter : 244 **********
# episode_reward_mean: -129.20130014228474
# ********** Iter : 245 **********
# episode_reward_mean: -127.33502930895138
# ********** Iter : 246 **********
# episode_reward_mean: -124.46475847561807
# ********** Iter : 247 **********
# episode_reward_mean: -127.98652930895142
# ********** Iter : 248 **********
# episode_reward_mean: -131.99921680895142
# ********** Iter : 249 **********
# episode_reward_mean: -132.75863347561807
# ********** Iter : 250 **********
# episode_reward_mean: -135.02432097561808
# ********** Iter : 251 **********
# episode_reward_mean: -136.3717376422847
# ********** Iter : 252 **********
# episode_reward_mean: -121.92050847561808
# ********** Iter : 253 **********
# episode_reward_mean: -128.41498764228473
# ********** Iter : 254 **********
# episode_reward_mean: -123.19215430895143
# ********** Iter : 255 **********
# episode_reward_mean: -122.7358834756181
# ********** Iter : 256 **********
# episode_reward_mean: -120.98760416666632
# ********** Iter : 257 **********
# episode_reward_mean: -128.76285416666627
# ********** Iter : 258 **********
# episode_reward_mean: -132.3216249999996
# ********** Iter : 259 **********
# episode_reward_mean: -129.73133333333294
# ********** Iter : 260 **********
# episode_reward_mean: -131.98035416666625
# ********** Iter : 261 **********
# episode_reward_mean: -130.12779166666627
# ********** Iter : 262 **********
# episode_reward_mean: -130.49310416666626
# ********** Iter : 263 **********
# episode_reward_mean: -130.33229166666624
# ********** Iter : 264 **********
# episode_reward_mean: -126.97004166666628
# ********** Iter : 265 **********
# episode_reward_mean: -121.1817499999996
# ********** Iter : 266 **********
# episode_reward_mean: -118.4042291666663
# ********** Iter : 267 **********
# episode_reward_mean: -113.00002083333297
# ********** Iter : 268 **********
# episode_reward_mean: -120.79145833333295
# ********** Iter : 269 **********
# episode_reward_mean: -120.5287291666663
# ********** Iter : 270 **********
# episode_reward_mean: -117.95974999999962
# ********** Iter : 271 **********
# episode_reward_mean: -122.66408333333291
# ********** Iter : 272 **********
# episode_reward_mean: -120.01022916666625
# ********** Iter : 273 **********
# episode_reward_mean: -120.97999999999958
# ********** Iter : 274 **********
# episode_reward_mean: -122.63597916666622
# ********** Iter : 275 **********
# episode_reward_mean: -118.26343749999957
# ********** Iter : 276 **********
# episode_reward_mean: -116.41931249999956
# ********** Iter : 277 **********
# episode_reward_mean: -118.69389583333287
# ********** Iter : 278 **********
# episode_reward_mean: -111.93597916666624
# ********** Iter : 279 **********
# episode_reward_mean: -110.93889583333292
# ********** Iter : 280 **********
# episode_reward_mean: -107.97841666666625
# ********** Iter : 281 **********
# episode_reward_mean: -101.32252083333293
# ********** Iter : 282 **********
# episode_reward_mean: -96.55937499999963
# ********** Iter : 283 **********
# episode_reward_mean: -92.66166666666633
# ********** Iter : 284 **********
# episode_reward_mean: -89.53727083333298
# ********** Iter : 285 **********
# episode_reward_mean: -88.84745833333301
# ********** Iter : 286 **********
# episode_reward_mean: -92.37829166666631
# ********** Iter : 287 **********
# episode_reward_mean: -91.60122916666634
# ********** Iter : 288 **********
# episode_reward_mean: -97.41033333333299
# ********** Iter : 289 **********
# episode_reward_mean: -96.94462499999965
# ********** Iter : 290 **********
# episode_reward_mean: -99.66222916666631
# ********** Iter : 291 **********
# episode_reward_mean: -99.5089166666663
# ********** Iter : 292 **********
# episode_reward_mean: -107.96883333333294
# ********** Iter : 293 **********
# episode_reward_mean: -106.13806249999962
# ********** Iter : 294 **********
# episode_reward_mean: -104.91606249999963
# ********** Iter : 295 **********
# episode_reward_mean: -106.77256249999962
# ********** Iter : 296 **********
# episode_reward_mean: -107.75602083333291
# ********** Iter : 297 **********
# episode_reward_mean: -109.8428333333329
# ********** Iter : 298 **********
# episode_reward_mean: -113.86931249999958
# ********** Iter : 299 **********
# episode_reward_mean: -109.07787499999961
# ********** Iter : 300 **********
# episode_reward_mean: -108.92033333333298
# ********** Iter : 301 **********
# episode_reward_mean: -102.97710416666631
# ********** Iter : 302 **********
# episode_reward_mean: -100.148458333333
# ********** Iter : 303 **********
# episode_reward_mean: -104.48437499999966
# ********** Iter : 304 **********
# episode_reward_mean: -106.49612499999962
# ********** Iter : 305 **********
# episode_reward_mean: -108.41858333333295
# ********** Iter : 306 **********
# episode_reward_mean: -106.656395833333
# ********** Iter : 307 **********
# episode_reward_mean: -106.80197916666629
# ********** Iter : 308 **********
# episode_reward_mean: -110.35081249999959
# ********** Iter : 309 **********
# episode_reward_mean: -110.23737499999962
# ********** Iter : 310 **********
# episode_reward_mean: -107.38249999999962
# ********** Iter : 311 **********
# episode_reward_mean: -103.61622916666627
# ********** Iter : 312 **********
# episode_reward_mean: -106.21668749999962
# ********** Iter : 313 **********
# episode_reward_mean: -100.16014583333299
# ********** Iter : 314 **********
# episode_reward_mean: -99.0244791666663
# ********** Iter : 315 **********
# episode_reward_mean: -98.7223124999996
# ********** Iter : 316 **********
# episode_reward_mean: -98.08795833333295
# ********** Iter : 317 **********
# episode_reward_mean: -94.50437499999964
# ********** Iter : 318 **********
# episode_reward_mean: -91.6489166666663
# ********** Iter : 319 **********
# episode_reward_mean: -91.21691666666628
# ********** Iter : 320 **********
# episode_reward_mean: -90.85737499999965
# ********** Iter : 321 **********
# episode_reward_mean: -92.3795416666663
# ********** Iter : 322 **********
# episode_reward_mean: -88.95337499999967
# ********** Iter : 323 **********
# episode_reward_mean: -81.40637499999968
# ********** Iter : 324 **********
# episode_reward_mean: -81.25362499999969
# ********** Iter : 325 **********
# episode_reward_mean: -79.71172916666636
# ********** Iter : 326 **********
# episode_reward_mean: -79.82722916666636
# ********** Iter : 327 **********
# episode_reward_mean: -83.35470833333298
# ********** Iter : 328 **********
# episode_reward_mean: -80.23741666666636
# ********** Iter : 329 **********
# episode_reward_mean: -84.39593749999969
# ********** Iter : 330 **********
# episode_reward_mean: -84.567458333333
# ********** Iter : 331 **********
# episode_reward_mean: -84.48999999999965
# ********** Iter : 332 **********
# episode_reward_mean: -83.45672916666635
# ********** Iter : 333 **********
# episode_reward_mean: -82.3304374999997
# ********** Iter : 334 **********
# episode_reward_mean: -87.98454166666632
# ********** Iter : 335 **********
# episode_reward_mean: -88.642145833333
# ********** Iter : 336 **********
# episode_reward_mean: -88.60945833333302
# ********** Iter : 337 **********
# episode_reward_mean: -85.82981249999968
# ********** Iter : 338 **********
# episode_reward_mean: -87.959458333333
# ********** Iter : 339 **********
# episode_reward_mean: -87.809833333333
# ********** Iter : 340 **********
# episode_reward_mean: -88.34145833333304
# ********** Iter : 341 **********
# episode_reward_mean: -85.34891666666637
# ********** Iter : 342 **********
# episode_reward_mean: -80.7607499999997
# ********** Iter : 343 **********
# episode_reward_mean: -79.57268749999972
# ********** Iter : 344 **********
# episode_reward_mean: -79.29874999999971
# ********** Iter : 345 **********
# episode_reward_mean: -78.02479166666637
# ********** Iter : 346 **********
# episode_reward_mean: -76.38849999999971
# ********** Iter : 347 **********
# episode_reward_mean: -76.26968749999972
# ********** Iter : 348 **********
# episode_reward_mean: -73.93891666666639
# ********** Iter : 349 **********
# episode_reward_mean: -80.44183333333302
# ********** Iter : 350 **********
# episode_reward_mean: -82.20935416666633
# ********** Iter : 351 **********
# episode_reward_mean: -87.87010416666631
# ********** Iter : 352 **********
# episode_reward_mean: -92.01918749999966
# ********** Iter : 353 **********
# episode_reward_mean: -99.93779166666631
# ********** Iter : 354 **********
# episode_reward_mean: -95.93993749999964
# ********** Iter : 355 **********
# episode_reward_mean: -93.70454166666632
# ********** Iter : 356 **********
# episode_reward_mean: -98.96420833333295
# ********** Iter : 357 **********
# episode_reward_mean: -97.97799999999962
# ********** Iter : 358 **********
# episode_reward_mean: -99.00533333333293
# ********** Iter : 359 **********
# episode_reward_mean: -96.20256249999964
# ********** Iter : 360 **********
# episode_reward_mean: -101.86977083333294
# ********** Iter : 361 **********
# episode_reward_mean: -101.66445833333295
# ********** Iter : 362 **********
# episode_reward_mean: -113.1266458333329
# ********** Iter : 363 **********
# episode_reward_mean: -110.66831249999959
# ********** Iter : 364 **********
# episode_reward_mean: -114.21222916666626
# ********** Iter : 365 **********
# episode_reward_mean: -114.58562499999954
# ********** Iter : 366 **********
# episode_reward_mean: -116.68352083333292
# ********** Iter : 367 **********
# episode_reward_mean: -115.97847916666622
# ********** Iter : 368 **********
# episode_reward_mean: -116.23931249999956
# ********** Iter : 369 **********
# episode_reward_mean: -116.08760416666624
# ********** Iter : 370 **********
# episode_reward_mean: -118.02504166666623
# ********** Iter : 371 **********
# episode_reward_mean: -119.26954166666623
# ********** Iter : 372 **********
# episode_reward_mean: -122.31095833333285
# ********** Iter : 373 **********
# episode_reward_mean: -124.93849999999954
# ********** Iter : 374 **********
# episode_reward_mean: -118.2610833333329
# ********** Iter : 375 **********
# episode_reward_mean: -115.48712499999958
# ********** Iter : 376 **********
# episode_reward_mean: -109.88372916666626
# ********** Iter : 377 **********
# episode_reward_mean: -108.12093749999958
# ********** Iter : 378 **********
# episode_reward_mean: -101.25879166666626
# ********** Iter : 379 **********
# episode_reward_mean: -98.54718749999958
# ********** Iter : 380 **********
# episode_reward_mean: -101.17681249999958
# ********** Iter : 381 **********
# episode_reward_mean: -99.38658333333291
# ********** Iter : 382 **********
# episode_reward_mean: -97.36141666666623
# ********** Iter : 383 **********
# episode_reward_mean: -94.47635416666624
# ********** Iter : 384 **********
# episode_reward_mean: -97.65577083333288
# ********** Iter : 385 **********
# episode_reward_mean: -94.72674999999954
# ********** Iter : 386 **********
# episode_reward_mean: -94.92124999999955
# ********** Iter : 387 **********
# episode_reward_mean: -83.31968749999963
# ********** Iter : 388 **********
# episode_reward_mean: -85.52945833333295
# ********** Iter : 389 **********
# episode_reward_mean: -81.90616666666628
# ********** Iter : 390 **********
# episode_reward_mean: -77.56562499999961
# ********** Iter : 391 **********
# episode_reward_mean: -75.3459166666663
# ********** Iter : 392 **********
# episode_reward_mean: -96.36981682170544
# ********** Iter : 393 **********
# episode_reward_mean: -96.63771265503878
# ********** Iter : 394 **********
# episode_reward_mean: -96.78662932170542
# ********** Iter : 395 **********
# episode_reward_mean: -94.27612932170547
# ********** Iter : 396 **********
# episode_reward_mean: -90.5232959883721
# ********** Iter : 397 **********
# episode_reward_mean: -87.27381682170551
# ********** Iter : 398 **********
# episode_reward_mean: -120.19635848837208
# ********** Iter : 399 **********
# episode_reward_mean: -120.0820459883721
# ********** Iter : 400 **********
# episode_reward_mean: -117.99483765503878
# ********** Iter : 401 **********
# episode_reward_mean: -124.18552515503877
# ********** Iter : 402 **********
# episode_reward_mean: -118.03112932170546
# ********** Iter : 403 **********
# episode_reward_mean: -123.62400432170546
# ********** Iter : 404 **********
# episode_reward_mean: -125.51290015503875
# ********** Iter : 405 **********
# episode_reward_mean: -124.19281682170543
# ********** Iter : 406 **********
# episode_reward_mean: -120.50744182170551
# ********** Iter : 407 **********
# episode_reward_mean: -120.2767543217055
# ********** Iter : 408 **********
# episode_reward_mean: -121.4750043217055
# ********** Iter : 409 **********
# episode_reward_mean: -117.71540015503886
# ********** Iter : 410 **********
# episode_reward_mean: -112.76194182170555
# ********** Iter : 411 **********
# episode_reward_mean: -112.60162932170554
# ********** Iter : 412 **********
# episode_reward_mean: -115.15219182170551
# ********** Iter : 413 **********
# episode_reward_mean: -112.8026709883722
# ********** Iter : 414 **********
# episode_reward_mean: -114.87142098837218
# ********** Iter : 415 **********
# episode_reward_mean: -114.88973348837217
# ********** Iter : 416 **********

# %% [markdown]
# By default, the results will be logged to a subdirectory of `~/ray_results`. This subdirectory will contain a file `params.json` which contains the hyperparameters, a file `result.json` which contains a training summary for each episode and a TensorBoard file that can be used to visualize training process with TensorBoard by running|
# ```shell
# tensorboard --logdir ~/ray_results
# ```

# %% [markdown]
# ## 4. Generate and Visualize the Environment's Dense Logs

# %% [markdown]
# At any point during training, we would also want to inspect the environment's dense logs in order to deep-dive into the training results. Introduced in our [basic tutorial](https://github.com/salesforce/ai-economist/blob/master/tutorials/economic_simulation_basic.ipynb#Visualize-using-dense-logging), dense logs are basically logs of each agent's states, actions and rewards at every point in time, along with a snapshot of the world state.
#
# There are two equivalent ways to fetch the environment's dense logs using the trainer object.
#
# a. Simply retrieve the dense log from the workers' environment objects
#
# b. Generate dense log(s) from the most recent trainer policy model weights

# %% [markdown]
# ### 4a. Simply retrieve the dense log from the workers' environment objects

# %% [markdown]
# From each rollout worker, it's straightforward to retrieve the dense logs using some of the function attributes.

# %%
# Below, we fetch the dense logs for each rollout worker and environment within

dense_logs = {}
# Note: worker 0 is reserved for the trainer actor
for worker in range((trainer_config["num_workers"] > 0), trainer_config["num_workers"] + 1):
    for env_id in range(trainer_config["num_envs_per_worker"]):
        dense_logs["worker={};env_id={}".format(worker, env_id)] = \
        trainer.workers.foreach_worker(lambda w: w.async_env)[worker].envs[env_id].env.previous_episode_dense_log

# %%
# We should have num_workers x num_envs_per_worker number of dense logs
print(dense_logs.keys())

# %% [markdown]
# ### 4b. Generate a dense log from the most recent trainer policy model weights

# %% [markdown]
# We may also use the trainer object directly to play out an episode. The advantage of this approach is that we can re-sample the policy model any number of times and generate several rollouts.

# %%
def generate_rollout_from_current_trainer_policy(
    trainer, 
    env_obj,
    num_dense_logs=1,
    plot_every=10
):
    dense_logs = {}
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    for idx in range(num_dense_logs):
        # Set initial states
        agent_states = {}
        for agent_idx in range(env_obj.env.n_agents):
            agent_states[str(agent_idx)] = trainer.get_policy("a").get_initial_state()
        planner_states = trainer.get_policy("p").get_initial_state()   

        # Play out the episode
        obs = env_obj.reset(force_dense_logging=True)
        for t in range(env_obj.env.episode_length):
            actions = {}
            for agent_idx in range(env_obj.env.n_agents):
                # Use the trainer object directly to sample actions for each agent
                actions[str(agent_idx)] = trainer.compute_action(
                    obs[str(agent_idx)], 
                    agent_states[str(agent_idx)], 
                    policy_id="a",
                    full_fetch=False
                )

            # Action sampling for the planner
            actions["p"] = trainer.compute_action(
                obs['p'], 
                planner_states, 
                policy_id='p',
                full_fetch=False
            )

            obs, rew, done, info = env_obj.step(actions)        
            if done['__all__']:
                break
        dense_logs[idx] = env_obj.env.dense_log   
    return dense_logs

# %%
dense_logs = generate_rollout_from_current_trainer_policy(
    trainer, 
    env_obj,
    num_dense_logs=4
)

# %% [markdown]
# ### Visualizing the episode dense logs

# %% [markdown]
# Once we obtain the dense logs, we can use the plotting utilities we have created to examine the episode dense logs and visualize the the world state, agent-wise quantities, movement, and trading events.

# %%
from utils import plotting  # plotting utilities for visualizing env. state

dense_log_idx = len(dense_logs)-1
plotting.breakdown(dense_logs[dense_log_idx]);

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython import display
from ai_economist.foundation.scenarios.utils import social_metrics


def do_plot(env, ax, fig):
    """Plots world state during episode sampling."""
    plotting.plot_env_state(env, ax)
    ax.set_aspect('equal')
    display.display(fig)
    display.clear_output(wait=True)

def play_random_episode(env, plot_every=100, do_dense_logging=False):
    """Plays an episode with randomly sampled actions.
    
    Demonstrates gym-style API:
        obs                  <-- env.reset(...)         # Reset
        obs, rew, done, info <-- env.step(actions, ...) # Interaction loop
    
    """
    
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))

    # Reset
    obs = env.reset(force_dense_logging=do_dense_logging)
    agent_states = {}
    for agent_idx in range(env_obj.env.n_agents):
        agent_states[str(agent_idx)] = trainer.get_policy("a").get_initial_state()
    planner_states = trainer.get_policy("p").get_initial_state()   


    for t in range(env_obj.env.episode_length):
        actions = {}
        for agent_idx in range(env_obj.env.n_agents):
            # Use the trainer object directly to sample actions for each agent
            actions[str(agent_idx)] = trainer.compute_action(
                obs[str(agent_idx)], 
                agent_states[str(agent_idx)], 
                policy_id="a",
                full_fetch=False
            )

        # Action sampling for the planner
        actions["p"] = trainer.compute_action(
            obs['p'], 
            planner_states, 
            policy_id='p',
            full_fetch=False
        )

        obs, rew, done, info = env_obj.step(actions)  

        if ((t+1) % plot_every) == 0:
            do_plot(env.env, ax, fig)

        if ((t+1) % plot_every) != 0:
            do_plot(env.env, ax, fig) 
    if do_dense_logging:
        plotting.breakdown(env_obj.env.dense_log)
    coin_endowments = np.array([agent.total_endowment("Coin") for agent in env_obj.env.world.agents])
    print("equality: {}".format(social_metrics.get_equality(coin_endowments)))
    print("Productivity: {}".format(social_metrics.get_productivity(coin_endowments)))
    print("lambda: {}".format(lambd))
    print("ethic: {}".format(ethics))

# %%
coin_endowments = np.array([agent.total_endowment("Coin") for agent in env_obj.env.world.agents])
print("equality: {}".format(social_metrics.get_equality(coin_endowments)))
print("Productivity: {}".format(social_metrics.get_productivity(coin_endowments)))
print("lambda: {}".format(lambd))
print("ethic: {}".format(ethics))

# %%
# Shutdown Ray after use
ray.shutdown()

# %% [markdown]
# And that's it for now. See you in the [next](https://github.com/salesforce/ai-economist/blob/master/tutorials/two_level_curriculum_learning_with_rllib.md) tutorial :)
